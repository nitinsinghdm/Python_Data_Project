# %% [markdown]
# # **Python Standard Libraries**

# %% [markdown]
# # **Statistic Module**

# %%
salary_list = [200000, 800000, 750000, 350000, 550000]

# %%
import statistics

statistics.mean(salary_list)
# Out:
# 530000

# %%
from statistics import mean, mode, median, quantiles

print('Mean        :', mean(salary_list))
print('Median      :', median(salary_list))
print('Mode        :', mode(salary_list))
print('Quantiles   :', quantiles(salary_list))
# Out:
# Mean        : 530000
# Median      : 550000
# Mode        : 200000
# Quantiles   : [275000.0, 550000.0, 775000.0]

# %%
# Open the file in read mode
file = open('sample_data/california_housing_test.csv')

# Read the file
content = file.read()

# Close the file
file.close()

# Print the content
print(content)
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -122.050000,37.370000,27.000000,3885.000000,661.000000,1537.000000,606.000000,6.608500,344700.000000
# -118.300000,34.260000,43.000000,1510.000000,310.000000,809.000000,277.000000,3.599000,176500.000000
# -117.810000,33.780000,27.000000,3589.000000,507.000000,1484.000000,495.000000,5.793400,270500.000000
# -118.360000,33.820000,28.000000,67.000000,15.000000,49.000000,11.000000,6.135900,330000.000000
# -119.670000,36.330000,19.000000,1241.000000,244.000000,850.000000,237.000000,2.937500,81700.000000
# -119.560000,36.510000,37.000000,1018.000000,213.000000,663.000000,204.000000,1.663500,67000.000000
# -121.430000,38.630000,43.000000,1009.000000,225.000000,604.000000,218.000000,1.664100,67000.000000
# -120.650000,35.480000,19.000000,2310.000000,471.000000,1341.000000,441.000000,3.225000,166900.000000
# ...

# %% [markdown]
# # **Pandas Overview**

# %%
import pandas as pd

content = pd.read_csv('sample_data/california_housing_test.csv')

content
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
content['population']
# Out:
# 0       1537.0
# 1        809.0
# 2       1484.0
# 3         49.0
# 4        850.0
#          ...
# 2995    1258.0
# 2996    3496.0
# 2997     693.0
# 2998      46.0
# 2999     753.0
# Name: population, Length: 3000, dtype: float64

# %%
content['population'].sum()
# Out:
# np.float64(4208396.0)

# %%
# !pip install pandas

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
# !pip install pyjokes

# %%
import pyjokes

pyjokes.get_joke()
# Out:
# "Unix is user friendly. It's just very particular about who its friends are."

# %% [markdown]
# # **Common Third Party Libraries**
#
# Below are some common third party libraries used in data science:
#
# - **Pandas:** Offers data structures and operations for manipulating numerical tables and time series.
# - **NumPy:** Supports large, multi-dimensional arrays and matrices, along with a collection of high-level mathematical functions.
# - **Matplotlib:** A plotting library for creating static, animated, and interactive visualizations in Python.
# - **Seaborn:** Provides a high-level interface for drawing attractive and informative statistical graphics.
# - **SciPy:** Used for scientific and technical computing, offering modules for optimization, linear algebra, and more.
# - **Scikit-learn:** Implements a range of machine learning algorithms for data mining, data analysis, and machine learning tasks.
# - **Plotly:** Creates interactive and visually appealing graphs for web publication.

# %% [markdown]
# # **NumPy**

# %%
# Create a list of 1,00,000 salaries ranging from 50,000 to 1,50,000

import random

salary_list = [random.randint(50000, 150000) for _ in range(100000)]

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 58.7 ms ± 11.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 11.3 ms ± 3.27 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Job Titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Machine Learning Engineer', 'Data Engineer', 'AI Engineer'])

# Base Salaries
base_salaries = np.array([50000, 70000, 100000, 120000, np.nan])

#Bonus Rate
bonus_rates = np.array([0.1, 0.15, 0.2, 0.25, np.nan])

# %%
total_salaries = base_salaries + (base_salaries * bonus_rates)

total_salaries
# Out:
# array([ 55000.,  80500., 120000., 150000.,     nan])

# %%
print(np.nanmean(total_salaries))
# Out:
# 101375.0

# %% [markdown]
# # **Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df['households']
# Out:
# 0        606.0
# 1        277.0
# 2        495.0
# 3         11.0
# 4        237.0
#          ...
# 2995     607.0
# 2996    1036.0
# 2997     220.0
# 2998      14.0
# 2999     260.0
# Name: households, Length: 3000, dtype: float64

# %%
df.households
# Out:
# 0        606.0
# 1        277.0
# 2        495.0
# 3         11.0
# 4        237.0
#          ...
# 2995     607.0
# 2996    1036.0
# 2997     220.0
# 2998      14.0
# 2999     260.0
# Name: households, Length: 3000, dtype: float64

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
# Load the dataset
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
# Transforms dataset to dataframe
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# # Pandas: **Inspection**

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
df[['job_title_short', 'job_location']].head(10) # To call out columns with n number of rows
# Out:
#         job_title_short                  job_location
# 0  Senior Data Engineer                 Watertown, CT
# 1          Data Analyst  Guadalajara, Jalisco, Mexico
# 2         Data Engineer               Berlin, Germany
# 3         Data Engineer               San Antonio, TX
# 4         Data Engineer                Washington, DC
# 5         Data Engineer                      Anywhere
# 6  Senior Data Engineer                  Dearborn, MI
# 7         Data Engineer                      Anywhere
# 8      Business Analyst           Copenhagen, Denmark
# 9        Data Scientist                      Anywhere

# %%
df.iloc[99] # Provides the details of that index
# Out:
# job_title_short                                              Data Engineer
# job_title                Senior/Staff Data Engineer – Apache Spark (Jav...
# job_location                                                     Miami, FL
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                  California, United States
# job_posted_date                                        2023-09-12 13:09:28
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# ...

# %%
df.iloc[90:100] # Provides the details of that index to n number of columns through slicing
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# ...

# %%
df.iloc[90:100, 0:5]
# Provides the details of that index to n number of columns through slicing but with a specific column or n number of column
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# ...

# %%
df[['job_title_short', 'job_location']].iloc[90:100] # To call out columns with a range of index
# Out:
#          job_title_short                job_location
# 90        Data Scientist                   Australia
# 91        Data Scientist               Temuco, Chile
# 92         Data Engineer                    Anywhere
# 93          Data Analyst                    Anywhere
# 94         Data Engineer                    Lehi, UT
# 95         Data Engineer  Mumbai, Maharashtra, India
# 96         Data Engineer                Torrance, CA
# 97          Data Analyst              United Kingdom
# 98  Senior Data Engineer         Toronto, ON, Canada
# 99         Data Engineer                   Miami, FL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
len(df) # For length
# Out:
# 785741

# %%
df.shape # To get rows and column
# Out:
# (785741, 17)

# %%
df.index # Tells about the indexing
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.columns # Gives the columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df.count() # Gives the count of rows in particular column
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df.job_title_short.unique() # Gives the unique values of the column
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[df.job_title_short == 'Data Analyst'].head() # Gives all the rows which matches the arg
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 50000)].head()
# Out:
#      job_title_short                                    job_title  \
# 109     Data Analyst        Senior Supply Chain Analytics Analyst
# 180     Data Analyst                             Data Analyst III
# 410     Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988     Data Analyst                        DATA ANALYST (ONSITE)
# 1413    Data Analyst                          Junior BI Developer
#
#             job_location                job_via job_schedule_type  \
# 109             Anywhere             via Get.It         Full-time
# 180        Dos Palos, CA  via My ArkLaMiss Jobs         Full-time
# 410   Atlantic Beach, FL   via ComputerJobs.com         Full-time
# 988      Springfield, MA             via Indeed         Full-time
# 1413         Atlanta, GA        via Ai-Jobs.net         Full-time
#
#       job_work_from_home            search_location      job_posted_date  \
# 109                 True    Illinois, United States  2023-10-12 13:02:19
# ...

# %%
df[df.salary_year_avg.notna()].head() # Gives the values in a column which are not null
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# # Pandas: **Data Cleaning**

# %%
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
type(df.job_posted_date[0])
# Out:
# str

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df.info() # Still an object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info() # Converted to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.year.head()
# Out:
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2023
# Name: job_posted_date, dtype: int32

# %%
df.job_posted_date.dt.month.head(10)
# Out:
# 0     6
# 1     1
# 2    10
# 3     7
# 4     8
# 5    11
# 6     3
# 7    12
# 8     6
# 9     4
# Name: job_posted_date, dtype: int32

# %%
# To add the new month column

df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.sort_values('job_posted_month', inplace=True)

# %%
df
# Out:
#           job_title_short                                          job_title  \
# 335487     Data Scientist                                       Data Modeler
# 335486  Software Engineer                        Principal Software Engineer
# 335485      Data Engineer                            Es- Data Engineer Azure
# 39          Data Engineer                                      Data Engineer
# 472238     Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 309117     Data Scientist                                     Data Scientist
# 363983       Data Analyst  Luxury Retail - Regional Data Insight Consulta...
# 139582      Data Engineer                                      Data Engineer
# 139580     Data Scientist                                     Data Scientist
# 335504       Data Analyst                                      Data Analysis
#
# ...

# %%
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df
# Out:
#           job_title_short                                          job_title  \
# 335487     Data Scientist                                       Data Modeler
# 335486  Software Engineer                        Principal Software Engineer
# 335485      Data Engineer                            Es- Data Engineer Azure
# 39          Data Engineer                                      Data Engineer
# 472238     Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 309117     Data Scientist                                     Data Scientist
# 363983       Data Analyst  Luxury Retail - Regional Data Insight Consulta...
# 139582      Data Engineer                                      Data Engineer
# 139580     Data Scientist                                     Data Scientist
# 335504       Data Analyst                                      Data Analysis
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 335487 to 335504
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset='salary_year_avg', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 335447 to 527579
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %% [markdown]
# # Pandas: **Analyzing**

# %%
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.salary_year_avg.median()
# Out:
# 115000.0

# %%
df.salary_year_avg.min()
# Out:
# 15000.0

# %%
min_salary = df.salary_year_avg.idxmin()

# %%
df.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].agg(['min', 'max', 'median'])
# Out:
#                           salary_year_avg                     salary_hour_avg  \
#                                       min       max    median             min
# job_title_short
# Business Analyst                  16500.0  387460.0   85000.0          10.835
# Cloud Engineer                    42000.0  280000.0   90000.0          18.500
# Data Analyst                      25000.0  650000.0   90000.0           8.000
# Data Engineer                     15000.0  525000.0  125000.0           8.000
# Data Scientist                    27000.0  960000.0  127500.0           8.000
# Machine Learning Engineer         30000.0  325000.0  106415.0          10.000
# Senior Data Analyst               30000.0  425000.0  111175.0          13.000
# Senior Data Engineer              35000.0  425000.0  147500.0          12.500
# Senior Data Scientist             45000.0  890000.0  155500.0          17.500
# Software Engineer                 28000.0  375000.0   99150.0          11.000
#
#
# ...

# %%
df.groupby(['job_title_short', 'job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %% [markdown]
# # Pandas: **Exercise**

# %%
# Install dataset library
# !pip install datasets

# Import Libraries
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
de_jobs = df[df['job_country'] == 'Germany']

# %%
de_jobs = de_jobs[de_jobs['salary_year_avg'].notna()]

de_jobs
# Out:
#                   job_title_short  \
# 1363               Data Scientist
# 7772                Data Engineer
# 10610        Senior Data Engineer
# 16764         Senior Data Analyst
# 20066                Data Analyst
# ...                           ...
# 781105               Data Analyst
# 781727  Machine Learning Engineer
# 782065  Machine Learning Engineer
# 784053             Data Scientist
# 785682             Data Scientist
#
#                                                 job_title  \
# 1363             Master Data Management Plants (f/m/div.)
# 7772        Research Engineer Bio-MEMS Sensors (f/m/div.)
# 10610        Senior Data Engineer - Infrastructure, TIDAL
# 16764                               Manager Data Strategy
# 20066                       Data Analyst Logistik (w/m/d)
# ...                                                   ...
# 781105                                       Data Analyst
# 781727        AI Product Owner - Manufacturing (f/m/div.)
# ...

# %%
de_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median' , 'min', 'max', 'count']).sort_values(by = 'median', ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      157500.0  80850.0  224500.0     21
# Data Engineer              147500.0  56700.0  200000.0     39
# Senior Data Engineer       147500.0  72900.0  155500.0     26
# Data Scientist             131560.0  56700.0  192000.0     41
# Senior Data Analyst        111175.0  57600.0  119400.0     15
# Data Analyst               103750.0  51014.0  200000.0     48
# Cloud Engineer              89100.0  80850.0  200000.0      7
# Business Analyst            89100.0  29900.0  126000.0     11
# Machine Learning Engineer   89100.0  44418.5  224500.0     39
# Software Engineer           84975.0  56700.0  177283.0     10

# %% [markdown]
# # **Matplotlib**

# %%
# Import Library

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5, 0.10)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# # Matplotlib: **Plotting**

# %%
# Install dataset library
#!pip install datasets

# Import Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Simple Example

x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

plt.plot(x, y)
plt.show()

# %%
# Plotting Job Posting dates

df.job_posted_date.head(10)
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# 5   2023-11-07 14:01:59
# 6   2023-03-27 13:18:18
# 7   2023-12-07 13:40:49
# 8   2023-06-05 13:44:34
# 9   2023-04-23 13:02:57
# Name: job_posted_date, dtype: datetime64[ns]

# %%
plt.plot(df.job_posted_date, df.job_posted_date)

# %%
date_counts = df.job_posted_date.value_counts()

date_counts = date_counts.sort_index()

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-01 00:00:04    1
# 2023-01-01 00:00:07    1
# 2023-01-01 00:00:22    1
# 2023-01-01 00:00:24    1
# 2023-01-01 00:00:27    1
#                       ..
# 2023-12-31 23:40:18    2
# 2023-12-31 23:40:22    2
# 2023-12-31 23:40:31    2
# 2023-12-31 23:40:32    1
# 2023-12-31 23:59:58    2
# Name: count, Length: 607192, dtype: int64

# %%
plt.plot(date_counts.index, date_counts)

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
monthly_count = df['job_posted_month'].value_counts()

monthly_count = monthly_count.sort_index()

monthly_count
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(monthly_count.index, monthly_count)
plt.show()

# %% [markdown]
# # Series vs DF
#
# - One Dimensional
# - Indexed
# - Diverse Data Types

# %%
series = pd.Series([11, 22, 33, 44, 55], index = ['a', 'b', 'c', 'd', 'e'])

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
series.values
# Out:
# array([11, 22, 33, 44, 55])

# %%
# Plot the counts of job postings
job_count = df['job_title_short'].value_counts().head(4)

job_count = job_count.sort_index()

job_count
# Out:
# job_title_short
# Business Analyst     49063
# Data Analyst        196075
# Data Engineer       186241
# Data Scientist      172286
# Name: count, dtype: int64

# %%
plt.bar(job_count.index, job_count)
plt.show()

# %%
job_count = df['job_title_short'].value_counts()

job_count
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
job_count = job_count.sort_values(ascending=True)
plt.barh(job_count.index, job_count)
plt.show()

# %% [markdown]
# # Matplotlib: **Labeling**

# %%
job_counts = df['job_title_short'].value_counts()

job_counts = job_counts.sort_index()

job_counts
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# Name: count, dtype: int64

# %%
job_counts = job_counts.sort_values(ascending=False)
plt.bar(job_counts.index, job_counts)
plt.title('Job Postings by Title')
plt.xlabel('Job Titles')
plt.ylabel('Count of Postings')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # **Matplotlib & Pandas**

# %%
job_counts.plot(kind = 'bar')
plt.ylabel('Count of Postings')
plt.xlabel('Job Titles')
plt.title('Job Postings by Title')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.plot(x='job_posted_date', y='salary_year_avg', kind='line')
plt.show()

# %% [markdown]
# # **Median Salary vs Data Science Jobs**
#
# Exercise

# %%
job_salary = df.groupby('job_title_short')['salary_year_avg'].median().sort_values()

# %%
job_salary.plot(kind='barh')
plt.xlabel('Median Salary ($USD)')
plt.ylabel('')
plt.title('Median Salary vs Data Science Jobs')
plt.show()
